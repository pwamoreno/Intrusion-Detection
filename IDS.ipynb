# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('Train_data.csv')
data.head()
# Out:
#    duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0          icmp       20     2        491          0     0
# 1         0           udp       45     2        146          0     0
# 2         0          icmp       50     4          0          0     0
# 3         0          icmp       25     2        232       8153     0
# 4         0          icmp       25     2        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
data_test = pd.read_csv('test_data.csv')
data_test = data_test.drop('Unnamed: 0',axis=1)
data_test.head()
# Out:
#    duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0          icmp       25     4          0          0     0
# 1         0          icmp       25     2        312       1856     0
# 2         0          icmp       25     2        245       2058     0
# 3         0          icmp       25     2        298       1267     0
# 4         0          icmp       20     2        740          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                 255
# 1               0       0    0  ...                 254
# 2               0       0    0  ...                 255
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                  19
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    1.00                    0.00
# 1                    1.00                    0.00
# 2                    1.00                    0.00
# ...

# %%
X_train = data.drop('xAttack', axis=1)
Y_train = data.loc[:,['xAttack']].values
X_test = data_test.drop('xAttack', axis=1)
Y_test = data_test.loc[:,['xAttack']].values

# %%
Y_train
# Out:
# array([['normal'],
#        ['normal'],
#        ['dos'],
#        ...,
#        ['normal'],
#        ['dos'],
#        ['normal']], dtype=object)

# %%
Y_test
# Out:
# array([['dos'],
#        ['normal'],
#        ['normal'],
#        ...,
#        ['normal'],
#        ['normal'],
#        ['r2l']], dtype=object)
