# %%
import pandas as pd 
import numpy as np
import seaborn as sb
import matplotlib as plt

data = pd.read_csv('Train_data.csv')
data.head()
# Out:
#    duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0          icmp       20     2        491          0     0
# 1         0           udp       45     2        146          0     0
# 2         0          icmp       50     4          0          0     0
# 3         0          icmp       25     2        232       8153     0
# 4         0          icmp       25     2        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
ds = data.loc[:,['protocol_type','count','xAttack']]

# %%
ds
# Out:
#        protocol_type  count xAttack
# 0               icmp      2  normal
# 1                udp     13  normal
# 2               icmp    123     dos
# 3               icmp      5  normal
# 4               icmp     30  normal
# ...              ...    ...     ...
# 125968          icmp    184     dos
# 125969           udp      2  normal
# 125970          icmp      1  normal
# 125971          icmp    144     dos
# 125972          icmp      1  normal
#
# [125973 rows x 3 columns]

# %%
sb.boxplot(x = 'protocol_type', y = 'count', data=data, palette='hls')
# Out:
# <AxesSubplot:xlabel='protocol_type', ylabel='count'>
